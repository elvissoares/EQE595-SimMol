# %% [markdown]
# <a href="https://colab.research.google.com/github/elvissoares/EQE595-SimMol/blob/main/listas/Lista02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EQE595 - Modelagem e Simulação Molecular
#
# Autor: [Prof. Elvis do A. Soares](https://github.com/elvissoares)
#
# Contato: [elvis@peq.coppe.ufrj.br](mailto:elvis@peq.coppe.ufrj.br) - [Programa de Engenharia Química, PEQ/COPPE, UFRJ, Brasil](https://www.peq.coppe.ufrj.br/)
#
# ---
#
# ## Nome do Aluno:
#
# ## DRE:
#
#
# ---

# %% [markdown]
# ### Este Notebook deve ser entregue preenchido via e-mail para elvis@peq.coppe.ufrj.br até a próxima segunda-feira (11/05) com horário limite de 23:59.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Questão 1:  Dinâmica Molecular no Ensemble NVE

# %% [markdown]
# a) Copie a classe `LJsystem` e as funções de interesse da aula `3_Ensemble_NVE.ipynb` para o seguinte bloco de código:

# %% [markdown]
# b) Inicialize o sistema com 864 partículas e use $\sigma=1$, $\epsilon=1$ e $m=1$.

# %% [markdown]
# c) Para $\rho^* = 0.2$ faça uma simulação NVE com 5000 passos no total com $h=0.003$ e escrevendo os resultados a cada 50 passos.

# %% [markdown]
# d) Faça um gráfico da evolução de $E$, $K$ e $U$ como função do tempo. E determine as médias e os desvios padrões de $E$, $U$ e $K$ assumindo que os primeiros 200 passos devem ser descartados.

# %% [markdown]
# e) Faça um gráfico das distribuições finais de velocidade $v_x$, $v_y$ e $v_z$ e compare com a distribuição gaussiana.
